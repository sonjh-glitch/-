# %% [markdown]
# ##파이썬

# %% [markdown]
# #변수

# %% [markdown]
# 정의 값을 저장하는 메모리 공간
# 변수이름과 값을 할당하여 생성 이름은 식별자를 통해 변수 사용동안 값을 바꿀 수 있다

# %% [markdown]
# 1 #자료형

# %% [markdown]
# 1. 1 숫자형
#
# 1. 1.1 정수형 int
# 음, 양의 정수  0 등 정수값
# -5 -3 0 31
#
# 1. 1.2 실수형 float
# 소수점이 포함된 숫자
# -5.0 -1.23 0.0 5.0 9.15
#
# 1.1.3 8진수 octal
# 0o 0O (숫자 0 + 알파벳 o 대소문자)
#
#
# 1.1.4 16진수 hexadecimal
# 0x

# %% [markdown]
# 1.1.5 연산자
# 사칙연산+ - * /
# 제곱 ** 나머지 %  몫 //
# 1.1.6 복합 연산자
# += = a + 1
# -= = a - 1
# *=, /=, //=, %=, **=

# %%
a = 10 b = 5
result = a+b
print(result)
# Out:
#   Cell In[1], line 1
#     a=10 b=5
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1.2 문자열 string str
#
# 문자들의 집합 문자 단어의 모임으로 구성
#
# 방법 4 " ' """ ''' (양쪽에 작은 , 큰따옴표 /  1,3)
#
# 영어에서 I'm 쓰는 경우 겹쳐져 헷갈리수가 있다

# %% [markdown]
# 1.2.1 이스케이프 문자 특수 문자
# \
# \n 줄바꿈 \t 탭 \\ 백슬래쉬 \' 작은따옴표 \" 큰따옴표
#
# \r 줄바꿈 커서를 가장 앞으로 이동 \f 피드 커서를 다음줄로 이동
# \a 출력시 삑 소리 \b 백스페이스 \000

# %% [markdown]
# 1.2.2 연산
# + *
# a = 'the'
# b = 'boyz'
# a+b
# 'theboyz'

# %% [markdown]
# 1.2.3 함수
# COUNT( )  특정 문자의 개수
# 	    print (text.count( 'a' ))
#
# JOIN ( )  사이사이에 특정 문자를 삽입하는 함수
# 	    print(',' . join (text)) ' '사이에 원하는 거 넣기 . 스페이스 + 이런거
#
# UPPER ( ) 모두 대문자로
# 	    print (text.upper( ))
#
# LOWER ()  소문자로  변경
# 	    print (text.lower( ))
#
# STRIP ()  공백 없애기 얼마든 다 없앰
# LSTRIP()  왼쪽 공백 없애기
# RSTRIP()  오른쪽 공백 없애기
# SPLIT ()  특정 기준에 따라 분리 형식 지정 X 공백 TAB 엔터로 분리
#           지정하면 맞추어서 분리 결과 리스트 형식
# 	    print (text.spilt( ))
#
# REPLACE   원하는 문자열로 바꿈
# 	    print (text.upper( ))

# %% [markdown]
# 인덱싱 가리킨다
# 슬라이싱 잘라낸다

# %% [markdown]
# 공통 예
#     a = life is too short
#         01234567891011121311516 (0부터 시작)
#
# 1.2.4 인덱싱
#  한문자 뽑아낼때 주로 사용 [원하는 자리 숫자]
#
# a[3] -> e (4번째 자리 문자)
# a[-1] -> n (뒤에서 첫번째 = 마지막 자리 문자)
# a[-0] = a [0]
#
# 1.2.5 슬라이싱
#  단어를 뽑아 낼때 사용
#  [시작:끝] 끝자리 포함 x [:끝] 맨처음부터 시작 [시작:] 맨 뒤까지
#  [:] 처음부터 끝까지
#
#  a[0:4] -> Life

# %% [markdown]
# 1.2.6 포매팅
#
# 특정 값을 바꿔야할때 사용
#
# "I eat () apples." % {}
# -> 'I eat {} apples.'
#
#
# 1 숫자 %d
# () : %d  {} : 원하는 숫자
#  이때 %d '문자열 포맷 코드'
#
# 2 문자열 대입 %s
# () : %s  {} : 원하는 문자
#
# 3 1개
# 위의 예문 위에 n = 원하는 숫자 추가
# () = %d {} = n
#
# 4 2개이상
# 위의 예문 위에 n = 원하는 숫자 추가
# day = "원하는 문자"
# () = %d {} = number,day

# %%
시퀀스 자료형 3 4

# %%
1.3 리스트
순서가 있는 변경 가능 자료형 
-모든 종류의 문자열을 나눔
-대괄호 사용
-생성 my list = [ 10,20,30] 				
 빈리스트 my_list = [ ]
         my_list 
         a = [ 2 , "문자열" , -.0.5 , '안녕' ]

# %%
a = [ 2 , "문자열" , -.0.5 , '안녕' ]
print("a[0]" , str(a[0]))
문자열
print("a[1][0]:"+a[0][1] ) 
문

# %% [markdown]
# 1.3.1 함수
#
# 수정 직접 접근
# 삭제 del
# 	del a[0]
# 추가 append( ) 함수 사용 맨 뒤에만 사용가능
# 	a.append(4)
#
# SORT ( ) 리스트 오름차순
# 	a.sort ( )
#
# REVERSE ( )
# INSERT ( )삽입
# 	a.insert ('')
#
# REMOVE ( ) 값을 기준으로 제거 중복값을 기주능로 1개
# 	a.remove ( )
#
# POP( ) 원하는 위치에 있는 요소 추출
# 	b = a.pop(2)
#
# COUNT ( ) 원하는 요소의 개수 세기

# %% [markdown]
# 복합자료형 리스트 튜플 딕셔너리 집합

# %% [markdown]
# 1.4 튜플
# 파이썬에서만 사용
# 순서가 있음 변경 불가능 자료형 소괄호 사용

# %% [markdown]
# 1.5 딕셔너리
# 키와 값을 쌍으로 데이터로 젇장하는 구조
# 순서가 없음 . 키는 유일 값(고유값)은 중복될수가 없음 문법적에러는 발생하지 않지만 안됨
# ex)
# my dict = [ 'name' :  'address']
# 수정추가삭제 가능
# 키 값 모든 값을 다 적용ㄱㄴ 리스트 사용 불ㄱㄴ
# 인덱싱이랑 거의 개념적으로 유사
# 삭제 del
# 키 중복시 하나 제외 다 무시

# %% [markdown]
# 1.5.1 딕셔너리 메소드
# keys () 리스트 만들기
# values 리스트
# items 쌍 리스트 얻기
# dlear 씽 다 지우기
# get key 값 통해 values 얻기

# %% [markdown]
# 2-5.1
# 비교 연산자
# ==  같으면 참
# !=   다르면 참
# <    오른쪽보다 작으면 참
# >    왼쪽보다 작으면 참
#
# 2-5.2
# 논리 연산자
# AND 둘 다 참    T AND F -> F TTT TFF FTF FFF
# OR 하나라도 참 T OR F -> T TTT TFT FTT FFF
# NOT 값 반대     not T -> F not F -> T
#
# EX) a==b and b==c
# 숫자 문자 리스트 튜플 다 가능

# %% [markdown]
# 1.6 집합
# T/F (참 또는 거짓) 비교 논리에 사용
# 첫글자는 대문자로 작성해야만 인식

# %% [markdown]
# 1.7 볼 boolean
